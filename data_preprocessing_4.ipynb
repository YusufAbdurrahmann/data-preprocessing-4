# %% [markdown]
# <a href="https://colab.research.google.com/github/YusufAbdurrahmann/data-preprocessing-4/blob/main/data_preprocessing_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **Data Importing**

# %%
df = pd.read_csv("./dataset/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %% [markdown]
# # **Data Understanding**

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
df.describe()
# Out:
#                age          sex  ...         thal       target
# count  1025.000000  1025.000000  ...  1025.000000  1025.000000
# mean     54.434146     0.695610  ...     2.323902     0.513171
# std       9.072290     0.460373  ...     0.620660     0.500070
# min      29.000000     0.000000  ...     0.000000     0.000000
# 25%      48.000000     0.000000  ...     2.000000     0.000000
# 50%      56.000000     1.000000  ...     2.000000     1.000000
# 75%      61.000000     1.000000  ...     3.000000     1.000000
# max      77.000000     1.000000  ...     3.000000     1.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **Handling duplicated data**

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Rename of data**

# %%
df.columns = df.columns.str.capitalize()

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
sns.set_theme(style="dark")
sns.histplot(data = df, x = "Age",kde = "True", palette = "pastel")
plt.ylabel("Frekuensi")
plt.show()
# Out:
# <ipython-input-20-9724d69031b0>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data = df, x = "Age",kde = "True", palette = "pastel")

# %%
df["Target"].value_counts().plot(kind = "pie", autopct = "%1.1f%%")
# Out:
# <Axes: ylabel='count'>
